# %% [markdown]
# # Question 2

# %% [markdown]
# Step 0

# %%
import seaborn as sns

# %% [markdown]
# Step 1

# %%
train = pd.read_csv("store_data_train.csv")

# %%
train.head()
# Out:
#          Date  store  product  number_sold
# 0  2010-01-01      0        0          801
# 1  2010-01-02      0        0          810
# 2  2010-01-03      0        0          818
# 3  2010-01-04      0        0          796
# 4  2010-01-05      0        0          808

# %%
train.tail()
# Out:
#               Date  store  product  number_sold
# 230085  2018-12-27      6        9          890
# 230086  2018-12-28      6        9          892
# 230087  2018-12-29      6        9          895
# 230088  2018-12-30      6        9          899
# 230089  2018-12-31      6        9          912

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230090 entries, 0 to 230089
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Date         230090 non-null  object
#  1   store        230090 non-null  int64
#  2   product      230090 non-null  int64
#  3   number_sold  230090 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 7.0+ MB

# %%
train.describe()
# Out:
#                store        product    number_sold
# count  230090.000000  230090.000000  230090.000000
# mean        3.000000       4.500000     780.926107
# std         2.000004       2.872288     204.096737
# min         0.000000       0.000000     238.000000
# 25%         1.000000       2.000000     722.000000
# 50%         3.000000       4.500000     835.000000
# 75%         5.000000       7.000000     914.000000
# max         6.000000       9.000000    1205.000000

# %%
train.shape
# Out:
# (230090, 4)

# %%
test = pd.read_csv("store_data_test.csv")

# %%
test.head()
# Out:
#          Date  store  product  number_sold
# 0  2019-01-01      0        0          845
# 1  2019-01-02      0        0          851
# 2  2019-01-03      0        0          840
# 3  2019-01-04      0        0          842
# 4  2019-01-05      0        0          845

# %%
test.tail()
# Out:
#              Date  store  product  number_sold
# 25545  2019-12-27      6        9          901
# 25546  2019-12-28      6        9          926
# 25547  2019-12-29      6        9          913
# 25548  2019-12-30      6        9          899
# 25549  2019-12-31      6        9          886

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25550 entries, 0 to 25549
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         25550 non-null  object
#  1   store        25550 non-null  int64
#  2   product      25550 non-null  int64
#  3   number_sold  25550 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 798.6+ KB

# %%
test.describe()
# Out:
#               store       product   number_sold
# count  25550.000000  25550.000000  25550.000000
# mean       3.000000      4.500000    790.050802
# std        2.000039      2.872338    211.923573
# min        0.000000      0.000000    234.000000
# 25%        1.000000      2.000000    722.000000
# 50%        3.000000      4.500000    852.000000
# 75%        5.000000      7.000000    933.000000
# max        6.000000      9.000000   1110.000000

# %%
test.shape
# Out:
# (25550, 4)

# %%
train_3_5 = train[(train['store'] == 3) & (train['product'] == 5)]
train_3_5['Date'] = pd.to_datetime(train_3_5['Date'])
train_3_5 = train_3_5.set_index('Date')
# Out:
# <ipython-input-337-700c6b8bd8b3>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_3_5.head()
# Out:
#             store  product  number_sold
# Date
# 2010-01-01      3        5          369
# 2010-01-02      3        5          363
# 2010-01-03      3        5          354
# 2010-01-04      3        5          340
# 2010-01-05      3        5          350

# %%
train_3_5.tail()
# Out:
#             store  product  number_sold
# Date
# 2018-12-27      3        5          345
# 2018-12-28      3        5          345
# 2018-12-29      3        5          359
# 2018-12-30      3        5          355
# 2018-12-31      3        5          340

# %%
train_3_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3287 entries, 2010-01-01 to 2018-12-31
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   store        3287 non-null   int64
#  1   product      3287 non-null   int64
#  2   number_sold  3287 non-null   int64
# dtypes: int64(3)
# memory usage: 102.7 KB

# %%
train_3_5.describe()
# Out:
#         store  product  number_sold
# count  3287.0   3287.0  3287.000000
# mean      3.0      5.0   356.219349
# std       0.0      0.0    11.211474
# min       3.0      5.0   318.000000
# 25%       3.0      5.0   349.000000
# 50%       3.0      5.0   356.000000
# 75%       3.0      5.0   364.000000
# max       3.0      5.0   395.000000

# %%
train_3_5.shape
# Out:
# (3287, 3)

# %%
test_3_5 = test[(test['store'] == 3) & (test['product'] == 5)]
test_3_5['Date'] = pd.to_datetime(test_3_5['Date'])
test_3_5 = test_3_5.set_index('Date')
# Out:
# <ipython-input-343-3278524910f4>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_3_5.head()
# Out:
#             store  product  number_sold
# Date
# 2019-01-01      3        5          363
# 2019-01-02      3        5          343
# 2019-01-03      3        5          331
# 2019-01-04      3        5          339
# 2019-01-05      3        5          350

# %%
test_3_5.tail()
# Out:
#             store  product  number_sold
# Date
# 2019-12-27      3        5          343
# 2019-12-28      3        5          358
# 2019-12-29      3        5          364
# 2019-12-30      3        5          365
# 2019-12-31      3        5          353

# %%
test_3_5.describe()
# Out:
#        store  product  number_sold
# count  365.0    365.0   365.000000
# mean     3.0      5.0   350.252055
# std      0.0      0.0    10.686184
# min      3.0      5.0   317.000000
# 25%      3.0      5.0   343.000000
# 50%      3.0      5.0   351.000000
# 75%      3.0      5.0   358.000000
# max      3.0      5.0   382.000000

# %%
test_3_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-01-01 to 2019-12-31
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   store        365 non-null    int64
#  1   product      365 non-null    int64
#  2   number_sold  365 non-null    int64
# dtypes: int64(3)
# memory usage: 11.4 KB

# %%
test_3_5.shape
# Out:
# (365, 3)

# %%
sns.histplot(train_3_5['number_sold'])
plt.xlabel("Number Sold")
plt.ylabel("Frequency")
plt.title("Distribution of Number of Items Sold in Train")
# Out:
# Text(0.5, 1.0, 'Distribution of Number of Items Sold in Train')

# %%
sns.histplot(test_3_5['number_sold'])
plt.xlabel("Number Sold")
plt.ylabel("Frequency")
plt.title("Distribution of Number of Items Sold in Test")
# Out:
# Text(0.5, 1.0, 'Distribution of Number of Items Sold in Test')

# %% [markdown]
# Step 2

# %%
from statsmodels.tsa.stattools import adfuller
adft = adfuller (train_3_5['number_sold'], autolag = 'AIC')
output_df = pd.DataFrame({'Values': [adft[0], adft[1], adft[2], adft[3],
                                    adft[4]['1%'], adft[4]['5%'], adft[4]['10%']],
                         'Metric': ['Test Statistics', 'p-value', 'No. of lags used',
                                   'Number of observations used', 'critical value (1%)',
                                   'critical value (5%)', 'critical value (10%)']

                         })
print (output_df)
# Out:
#         Values                       Metric
# 0    -5.629986              Test Statistics
# 1     0.000001                      p-value
# 2    28.000000             No. of lags used
# 3  3258.000000  Number of observations used
# 4    -3.432359          critical value (1%)
# 5    -2.862428          critical value (5%)
# 6    -2.567242         critical value (10%)

# %%
from statsmodels.tsa.stattools import adfuller
adft = adfuller (test_3_5['number_sold'], autolag = 'AIC')
output_df = pd.DataFrame({'Values': [adft[0], adft[1], adft[2], adft[3],
                                    adft[4]['1%'], adft[4]['5%'], adft[4]['10%']],
                         'Metric': ['Test Statistics', 'p-value', 'No. of lags used',
                                   'Number of observations used', 'critical value (1%)',
                                   'critical value (5%)', 'critical value (10%)']

                         })
print (output_df)
# Out:
#          Values                       Metric
# 0 -1.188375e+01              Test Statistics
# 1  6.091690e-22                      p-value
# 2  3.000000e+00             No. of lags used
# 3  3.610000e+02  Number of observations used
# 4 -3.448595e+00          critical value (1%)
# 5 -2.869580e+00          critical value (5%)
# 6 -2.571053e+00         critical value (10%)

# %% [markdown]
# This is stationary because the p-value is less than 0.05.

# %% [markdown]
# Step 3

# %%
autocorr_lag1 = train_3_5['number_sold'].autocorr (lag = 1)
print ('One Month Lag: ', autocorr_lag1)
autocorr_lag3 = train_3_5['number_sold'].autocorr (lag = 3)
print ('Three Month Lag: ', autocorr_lag3)
autocorr_lag6 = train_3_5['number_sold'].autocorr (lag = 6)
print ('One Month Lag: ', autocorr_lag6)
autocorr_lag9 = train_3_5['number_sold'].autocorr (lag = 9)
print ('One Month Lag: ', autocorr_lag9)
# Out:
# One Month Lag:  0.1494285023901609
# Three Month Lag:  -0.07709915856406584
# One Month Lag:  0.11941717066655934
# One Month Lag:  0.03380432520804497

# %%
autocorr_lag1 = test_3_5['number_sold'].autocorr (lag = 1)
print ('One Month Lag: ', autocorr_lag1)
autocorr_lag3 = test_3_5['number_sold'].autocorr (lag = 3)
print ('Three Month Lag: ', autocorr_lag3)
autocorr_lag6 = test_3_5['number_sold'].autocorr (lag = 6)
print ('One Month Lag: ', autocorr_lag6)
autocorr_lag9 = test_3_5['number_sold'].autocorr (lag = 9)
print ('One Month Lag: ', autocorr_lag9)
# Out:
# One Month Lag:  0.12238437024776216
# Three Month Lag:  -0.2265519353989384
# One Month Lag:  0.0670513133173694
# One Month Lag:  -0.05957546081910322

# %% [markdown]
# Step 4

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

sd = seasonal_decompose (train_3_5['number_sold'], model = 'additive', period = 7)
sd.plot()
plt.show()

# %%
sd = seasonal_decompose (test_3_5['number_sold'], model = 'additive', period = 7)
sd.plot()
plt.show()

# %% [markdown]
# Step 5

# %%
from pmdarima.arima import auto_arima

model = auto_arima (train_3_5['number_sold'], trace = True, error_action = 'ignore', suppress_warnings = True)
model.fit (train_3_5['number_sold'])

forecast = model.predict (n_periods = len(test_3_5['number_sold']))
forecast = pd.DataFrame (forecast, index = test.index, columns = ['Prediction'])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=3.32 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=26957.535, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=26277.373, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=1.56 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=26955.536, Time=0.11 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=26098.579, Time=0.41 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=25942.536, Time=0.71 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=25732.089, Time=1.07 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=25488.653, Time=0.64 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=24908.559, Time=3.76 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=4.04 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=6.70 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=4.59 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=24908.084, Time=1.42 sec
# ...

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error
rms = sqrt (mean_squared_error (test_3_5['number_sold'], model.predict(n_periods = len(test_3_5['number_sold']))))
print ('RMSE: ', rms)
# Out:
# RMSE:  10.83073000240236

# %%
plt.plot (train_3_5['number_sold'], label = 'Train', color = 'black')
plt.plot (test_3_5['number_sold'], label = 'Test', color = 'red')
plt.plot (model.predict(n_periods = len(test_3_5['number_sold'])), label = 'Prediction', color = 'green')
plt.title ('Passenger Prediction')
plt.ylabel ('#Passenger')
plt.xlabel ('Date')
plt.legend (loc = 'upper left', fontsize = 8)
plt.show()
